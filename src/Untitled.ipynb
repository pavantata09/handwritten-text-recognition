# %%
import os
import cv2
from PIL import Image
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd

import numpy as np
# import pytesseract
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
img=cv2.imread('/data2/pavan/handwritten-text-recognition/src/images/s8.jpg')
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imwrite('greyimg.jpg',gray_image)
# Out:
# True

# %%
plt.imshow(gray_image)
plt.show()

# %%
out=pytesseract.image_to_string(Image.open('out.jpg'))
out

# %%
image = cv2.imread('/data2/pavan/Data/crop/15-2b.jpeg')
output = image
# Set thresholds. Here, we are using the Hue, Saturation, Value color space model. We will be using these values to decide what values to show in the ranges using a minimum and maximum value. 
# THESE VALUES CAN BE PLAYED AROUND FOR DIFFERENT COLORS
hMin = 50 # Hue minimum
sMin = 5 # Saturation minimum
vMin = 15  # Value minimum (Also referred to as brightness)
hMax = 179 # Hue maximum
sMax = 255 # Saturation maximum
vMax = 255 # Value maximum
# Set the minimum and max HSV values to display in the output image using numpys' array function. We need the numpy array since OpenCVs' inRange function will use those.
lower = np.array([hMin, sMin, vMin])
upper = np.array([hMax, sMax, vMax])
# Create HSV Image and threshold it into the proper range.
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV) # Converting color space from BGR to HSV
mask = cv2.inRange(hsv, lower, upper) # Create a mask based on the lower and upper range, using the new HSV image
# Create the output image, using the mask created above. This will perform the removal of all unneeded colors, but will keep a black background.
output = cv2.bitwise_and(image, image, mask=mask)
# Add an alpha channel, and update the output image variable
*_, alpha = cv2.split(output)
dst = cv2.merge((output, alpha))
output = dst
# Resize the image to 512, 512 (This can be put into a variable for more flexibility), and update the output image variable.
dim = (800, 100)

output = cv2.resize(output, dim)
# Generate a random file name using a mini helper function called randomString to write the image data to, and then save it in the processed_folder path, using the generated filename.
plt.imshow(output)
plt.show()

# %%
cv2.imwrite('noback.jpg',output)

# %%
img = cv2.imread('/data2/pavan/Data/crop/104-IMG-20200521-WA0009.jpg', cv2.IMREAD_GRAYSCALE)

# increase contrast
pxmin = np.min(img)
pxmax = np.max(img)
imgContrast = (img - pxmin) / (pxmax - pxmin) * 255

# increase line width
kernel = np.ones((3, 3), np.uint8)
imgMorph = cv2.erode(imgContrast, kernel, iterations = 1)

# write
cv2.imwrite('out.jpg', imgMorph)
plt.imshow(imgMorph)
plt.show()

# %%
df = pd.read_csv('/data2/pavan/via_export_csv12.csv')
text=df['region_attributes']
len(text)
t1=[]
text[1][9:-2]
for i in text:
    t=i[9:-2]
    s1=t.replace(' ','|')
    t1.append(s1)

# %%
with open('/data2/pavan/handwritten-text-recognition/raw/iam/largeWriterIndependentTextLineRecognitionTask/validationset1.txt','w') as f:
    for i in range(9000,10000):
        f.write(str(i)+ '\n')

# %%
ui[1]

# %%
img=cv2.imread('/data2/pavan/Data/crop/10-2a.jpeg')
ret,thresh2 = cv2.threshold(img,150,255,cv2.THRESH_BINARY_INV)

# %%
kernel = np.ones((3,1),np.uint8)
# closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)
dilation = cv2.dilate(img,kernel,iterations = 1)
# inpain = cv2.inpaint(img,masked_data,10,cv2.INPAINT_NS)
# opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
# erosion = cv2.erode(img,kernel,iterations = 1)
# gradient = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernel)
# tophat = cv2.morphologyEx(img, cv2.MORPH_TOPHAT, kernel)
# blackhat = cv2.morphologyEx(img, cv2.MORPH_BLACKHAT, kernel)

# %%
opening = cv2.morphologyEx(thresh2, cv2.MORPH_BLACKHAT, k)
plt.imshow(dilation)
plt.show()

# %%
k=np.array([[-2,-2],[-3,-2]],dtype=np.int16)

# %%
k

# %%
l=os.listdir('/data2/pavan/handwritten-text-recognition/raw/iam/lines/')

# %%
len(l)

# %%
# a01-003-04
import shutil

# %%
ui=[]
dir=os.getcwd()
for i in 'qs':
    for j in range(0,4):
        s=str(i)+'0'+str(j)
#         os.mkdir(s)
        for k in range(0,9):
            o=s+'-00'+str(k)
            os.chdir(dir+'/'+s)
            os.mkdir(o)
            for l in range(0,10):
                r=o+'-0'+str(l)
                ui.append(r)

# %%
dc={}
pth=''
for i,j in zip(l,ui[:710]):
    s=j.split('-')
    dc[i]=j+'.png'
    shutil.copy('/data2/pavan/handwritten-text-recognition/raw/iam/lines/'+i,'/data2/pavan/handwritten-text-recognition/src/'+s[0]+'/'+s[0]+"-"+s[1]+'/'+j+'.png')
    
#     print(s)
#     shutil.copy

# %%
len(ui[:710])

# %%
ori=[]
with open('/data2/pavan/handwritten-text-recognition/raw/iam/ascii/lines.txt','r')as f:
    for ki in f.readlines():
        ori.append(ki)

# %%
sp=ori[0].split()

# %%
sp[0],sp[-1]

# %%
new=[]
for u in ori:
    sp=u.split()
    new.append([dc[sp[0]+'.png'],sp[-1]])

# %%
new[1][0][:-4]

# %%
with open('/data2/pavan/handwritten-text-recognition/raw/iam/ascii/lines.txt','w')as f:
    for k in new:
        nam=k[0][:-4]
        line = nam + ' X X X X X X X ' + k[1] + '\n'
        f.write(line)

# %%
import argparse
import cv2
import h5py
import os
import string
import datetime

from data import preproc as pp, evaluation
from data.generator import DataGenerator, Tokenizer
from data.reader import Dataset
from network.model import HTRModel

input_size = (1024, 128, 1)
max_text_length = 128
charset_base = string.printable[:95]

tokenizer = Tokenizer(chars=charset_base, max_text_length=max_text_length)
image=input('enter your image path:')
img = pp.preprocess(image, input_size=input_size)
x_test = pp.normalization([img])

model = HTRModel(architecture=flor,
                 input_size=input_size,
                 vocab_size=tokenizer.vocab_size,
                 top_paths=10)

model.compile()
model.load_checkpoint(target=target_path)

predicts, probabilities = model.predict(x_test, ctc_decode=True)
predicts = [[tokenizer.decode(x) for x in y] for y in predicts]

print("\n####################################")
for i, (pred, prob) in enumerate(zip(predicts, probabilities)):
    print("\nProb.  - Predict")

    for (pd, pb) in zip(pred, prob):
        print(f"{pb:.4f} - {pd}")

    cv2.imshow(f"Image {i + 1}", cv2.imread(image))
print("\n####################################")
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-aae7e46cc21b> in <module>
#       1 import argparse
# ----> 2 import cv2
#       3 import h5py
#       4 import os
#       5 import string
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# !pip list
# Out:
# Package                            Version     Location
# ---------------------------------- ----------- --------------------------
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.7
# anaconda-project                   0.8.3
# appdirs                            1.4.4
# asn1crypto                         0.24.0
# astroid                            2.2.5
# astropy                            3.2.1
# atomicwrites                       1.3.0
# attrs                              19.1.0
# audioread                          2.1.6
# Babel                              2.7.0
# backcall                           0.1.0
# backports.functools-lru-cache      1.5
# backports.os                       0.1.1
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# beautifulsoup4                     4.7.1
# bitarray                           0.9.3
# ...
